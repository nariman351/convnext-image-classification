# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
thisdict = {
  "CN-R-NN": 99.62,
  "CN-R-SVM": 97.68,
  "CN-R-LR": 97.52,
  "CN-R-CatBoost": 97.21,
  "CN-R": 97.07,
  "CN-R-XGBoost": 97.03,
  "CN-R-NB": 95.96,
  "CN-Wandb": 95.41,
  "CN-P-SVM": 93.81,
  "CN-P-LR": 92.87,
  "CN-P": 92.59,
  "CN-P-NN": 92.20,
  "CN-P-CatBoost": 91.38,
  "CN-P-XGBoost": 88.95,
  "CN-P-NB": 86.27,
  "AN-FC6-LR": 81.35,
  "AN-FC7-LR": 80.51
}

# %%
df = pd.DataFrame(thisdict.items())
df
# Out:
#                 0      1
# 0         CN-R-NN  99.62
# 1        CN-R-SVM  97.68
# 2         CN-R-LR  97.52
# 3   CN-R-CatBoost  97.21
# 4            CN-R  97.07
# 5    CN-R-XGBoost  97.03
# 6         CN-R-NB  95.96
# 7        CN-Wandb  95.41
# 8        CN-P-SVM  93.81
# 9         CN-P-LR  92.87
# 10           CN-P  92.59
# 11        CN-P-NN  92.20
# 12  CN-P-CatBoost  91.38
# 13   CN-P-XGBoost  88.95
# 14        CN-P-NB  86.27
# 15      AN-FC6-LR  81.35
# 16      AN-FC7-LR  80.51

# %%
sns.set(rc={"figure.dpi":300, 'savefig.dpi':300})
sns.set_theme(style="whitegrid")
sns.barplot(x=df[1],y=df[0], palette= "Spectral")
plt.xlabel('Accuracy', fontsize=18)
plt.ylabel('Models', fontsize=16)
plt.xlim(80, 100)
plt.show()
